# %%
from deepface.commons import functions
import os
# Out:
# 2022-02-20 17:08:53.140232: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pcminh/social-profiling/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-02-20 17:08:53.140282: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import matplotlib.pyplot as plt

# %%
DATASET_BASE_PATH = '../tests/nguoinoitiengtv'

relative_path = "full/son_tung/son_tung_fb17c753647279683f313a90c33a89575057b2d0.jpg"

path = os.path.join(DATASET_BASE_PATH, relative_path)

# %% [markdown]
# # Detect and Align

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface']

img = functions.load_image(path)

face, region = functions.detect_face(img, detector_backend=backends[4])

plt.imshow(face)

print(region)
# Out:
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /home/pcminh/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:11<00:00, 10.4MB/s]
# [362, 183, 157, 212]

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface']

img = functions.load_image(path)

img = functions.preprocess_face(img=path, target_size=(160, 160), detector_backend=backends[4])[0]

plt.imshow(img)

# %% [markdown]
# # Normalization
