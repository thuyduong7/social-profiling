# %% [markdown]
# # Retrieving facial embeddings and building the index

# %%
from pymongo import MongoClient
import pymongo

CONNECTION_STRING = "mongodb://admin:admin@localhost:27018/?authSource=admin"

client = MongoClient(CONNECTION_STRING)
db = client['social_profiling']

profile_collection = db['eval_profiles']
face_collection = db['eval_embeddings']

# %%
faces = face_collection.find()
faces = list(faces)

# %%
import numpy as np

ids = []
embeddings = []
for face in faces:
    fid = face['_id']
    fid = fid.split('_')[-1]
    embedding = face['values']
    ids.append(fid)
    embeddings.append(embedding)

ids = np.array(ids, dtype='int64')
embeddings = np.array(embeddings, dtype='f')

# %%
print(ids.shape)
print(embeddings.shape)
# Out:
# (34796,)
# (34796, 128)

# %%
import faiss

dimensions = 128    # FaceNet output is 128d vector

metric = 'euclidean' #euclidean, cosine
 
if metric == 'euclidean':
    index = faiss.IndexFlatL2(dimensions)
elif metric == 'cosine':
    index = faiss.IndexFlatIP(dimensions)
    faiss.normalize_L2(embeddings)

index = faiss.IndexIDMap(index)

# %%
index.add_with_ids(embeddings, ids)

# %%
faiss.write_index(index, "./test.index")

# %%
split_path = '../tests/nguoinoitiengtv/split/'
import os
train_path = os.path.join(split_path, 'train')
val_path = os.path.join(split_path, 'val')

# %%
import json
f2p_map = []

with open( os.path.join(split_path, 'filename_profile_map.json'), 'r' ) as f:
    f2p_map = json.load(f)

# %%
import pandas as pd

df = pd.DataFrame.from_dict(f2p_map, orient='index')

df.columns = ['truth']
df['is_in_val'] = np.nan
df['has_detect_face'] = np.nan
df['prediction'] = np.nan

df
# Out:
#                                                              truth  is_in_val  \
# son_tung_2f2254a088377df162f65714467920756d42bd...  profile_000000        NaN
# son_tung_5f3fcaef2ee07436a10993d42e2825eb8a29e4...  profile_000000        NaN
# son_tung_1bfcf9ab4f2f7d07f4d01a46e790ed8a37b437...  profile_000000        NaN
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000        NaN
# son_tung_c90fb40c95e77c2f78e5a9e7d21df11021145e...  profile_000000        NaN
# ...                                                            ...        ...
# nguyen_thi_mai_ka_1199de669876527412fbbe810cd94...  profile_012524        NaN
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...  profile_012524        NaN
# nguyen_thi_mai_ka_3a4456452f42cda05b3e06002535f...  profile_012524        NaN
# nguyen_thi_mai_ka_b40d03f5243adc2892d99fa3d1589...  profile_012524        NaN
# nguyen_thi_mai_ka_492d4a27f400a57e929096a63a3a9...  profile_012524        NaN
#
#                                                     has_detect_face  \
# son_tung_2f2254a088377df162f65714467920756d42bd...              NaN
# son_tung_5f3fcaef2ee07436a10993d42e2825eb8a29e4...              NaN
# son_tung_1bfcf9ab4f2f7d07f4d01a46e790ed8a37b437...              NaN
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...              NaN
# son_tung_c90fb40c95e77c2f78e5a9e7d21df11021145e...              NaN
# ...                                                             ...
# nguyen_thi_mai_ka_1199de669876527412fbbe810cd94...              NaN
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...              NaN
# nguyen_thi_mai_ka_3a4456452f42cda05b3e06002535f...              NaN
# nguyen_thi_mai_ka_b40d03f5243adc2892d99fa3d1589...              NaN
# nguyen_thi_mai_ka_492d4a27f400a57e929096a63a3a9...              NaN
#
#                                                     prediction
# son_tung_2f2254a088377df162f65714467920756d42bd...         NaN
# son_tung_5f3fcaef2ee07436a10993d42e2825eb8a29e4...         NaN
# son_tung_1bfcf9ab4f2f7d07f4d01a46e790ed8a37b437...         NaN
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...         NaN
# son_tung_c90fb40c95e77c2f78e5a9e7d21df11021145e...         NaN
# ...                                                        ...
# nguyen_thi_mai_ka_1199de669876527412fbbe810cd94...         NaN
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...         NaN
# nguyen_thi_mai_ka_3a4456452f42cda05b3e06002535f...         NaN
# nguyen_thi_mai_ka_b40d03f5243adc2892d99fa3d1589...         NaN
# nguyen_thi_mai_ka_492d4a27f400a57e929096a63a3a9...         NaN
#
# [53750 rows x 4 columns]

# %%
import os

base_path = val_path

val_filenames = []

for root, dirs, files in os.walk(base_path):
    if not dirs:
        for f in files:
            path = os.path.join(root, f)
            val_filenames.append(path)
            
len(val_filenames)
# Out:
# 13866

# %%
def get_id(prefix, suffix, rjust_fill=6):
    return (str(prefix) + str(suffix).rjust(rjust_fill, '0'))

# %%
from deepface.basemodels import Facenet
from deepface.commons import functions
model = Facenet.loadModel()

def get_closest_match(target_img_path, k, index):
    target_img = functions.preprocess_face(img=target_img_path, target_size=(160, 160), detector_backend='mtcnn')
    target_representation = model.predict(target_img)[0,:]

    target_representation = np.array(target_representation, dtype='f')
    target_representation = np.expand_dims(target_representation, axis=0)

    distances, neighbors = index.search(target_representation, k)

    return distances, neighbors

# %%
from tqdm import tqdm
import numpy as np

test_result = {}

for path in tqdm(val_filenames[0:100]):
    head, tail = os.path.split(path)
    df.at[tail, 'is_in_val'] = True

    # try:
    #     preprocessed_faces[tail] = functions.preprocess_face(img=path, target_size=(160, 160))
    # except:
    #     df.at[tail, 'has_detect_face'] = False

    # # print(path)
    # # d, n = get_closest_match(path, 1, index)
    # # print(path, d, n)
    try:
        d, n = get_closest_match(path, 20, index)
    except ValueError:
        df.at[tail, 'has_detect_face'] = False
        continue

    matches = face_collection.find(
        { "_id": { "$in": [get_id("embedding_", idnum) for idnum in n[0].tolist()] } },
        { "profile_id": 1 }
        )
    matches = list(matches)

    results = [ [ match['_id'], match['profile_id'], np.float64(distance) ] for match, distance in zip(matches, d[0]) ]

    test_result[tail] = results
            
    # match = face_collection.find_one({ "_id": get_id('embedding_', n[0][0]) }, { "profile_id": 1 })
    # profile_id = match['profile_id']

    # print(f"{d} {n} {profile_id}")
    
    # df.at[tail, 'prediction'] = profile_id
    df.at[tail, 'has_detect_face'] = True

import json
with open(os.path.join(split_path, 'test_result.json'), 'w') as f:
    json.dump(test_result, f)
print(f"Written test result to {os.path.join(split_path, 'test_result.json')}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]2022-02-23 10:40:39.339559: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-02-23 10:40:40.064840: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9bdc3eff70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9bdcc160d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# Written test result to ../tests/nguoinoitiengtv/split/test_result.json

# %%
test_result['dita_von_teese_eeeb1401545eb75a52c7d2c846f908c92865bf12.jpg'][0]
# Out:
# ('embedding_003408', 'profile_001251', 50.48596954345703)

# %%
with open(os.path.join(split_path, 'test_result.json'), 'r') as f:
    import_result = json.load(f)

# %%
import_result
# Out:
# {'dita_von_teese_eeeb1401545eb75a52c7d2c846f908c92865bf12.jpg': [['embedding_003408',
#    'profile_001251',
#    50.48596954345703],
#   ['embedding_004047', 'profile_001472', 60.60420227050781],
#   ['embedding_004048', 'profile_001472', 64.78118133544922],
#   ['embedding_004049', 'profile_001472', 92.24520874023438],
#   ['embedding_004050', 'profile_001472', 94.05899810791016],
#   ['embedding_004862', 'profile_001750', 98.48477935791016],
#   ['embedding_004863', 'profile_001750', 103.31478881835938],
#   ['embedding_004864', 'profile_001750', 105.87550354003906],
#   ['embedding_007195', 'profile_002543', 106.4572982788086],
#   ['embedding_007414', 'profile_002627', 106.69178771972656],
#   ['embedding_007913', 'profile_002787', 107.30900573730469],
#   ['embedding_014416', 'profile_005036', 109.97169494628906],
#   ['embedding_014417', 'profile_005036', 110.31056213378906],
#   ['embedding_019986', 'profile_007011', 112.51024627685547],
#   ['embedding_021804', 'profile_007658', 112.66697692871094],
#   ['embedding_022843', 'profile_008002', 114.38304901123047],
#   ['embedding_023003', 'profile_008062', 115.08485412597656],
#   ['embedding_026960', 'profile_009495', 115.71495819091797],
#   ['embedding_028304', 'profile_009963', 116.41842651367188],
#   ['embedding_028782', 'profile_010130', 117.07564544677734]],
#  'pham_hoang_nguyen_c87caf8cb0a21774aa7209bb1efb33427c908344.jpg': [['embedding_003456',
#    'profile_001268',
#    24.397666931152344],
#   ['embedding_004308', 'profile_001555', 40.40879440307617],
#   ['embedding_013372', 'profile_004678', 40.432464599609375],
#   ['embedding_013997', 'profile_004895', 41.343360900878906],
#   ['embedding_014768', 'profile_005164', 42.11250686645508],
#   ['embedding_015801', 'profile_005520', 42.8206901550293],
#   ['embedding_018812', 'profile_006589', 42.83268356323242],
#   ['embedding_019640', 'profile_006900', 43.610626220703125],
#   ['embedding_024792', 'profile_008690', 43.858829498291016],
#   ['embedding_025697', 'profile_009046', 43.93853759765625],
#   ['embedding_026579', 'profile_009357', 44.06357955932617],
#   ['embedding_027380', 'profile_009630', 44.49507522583008],
#   ['embedding_028578', 'profile_010055', 44.88964080810547],
#   ['embedding_030220', 'profile_010675', 45.1786003112793],
#   ['embedding_030815', 'profile_010924', 45.20866394042969],
#   ['embedding_031326', 'profile_011141', 45.68921661376953],
#   ['embedding_031469', 'profile_011198', 45.98163604736328],
#   ['embedding_032375', 'profile_011539', 46.2670783996582],
#   ['embedding_034260', 'profile_012300', 46.79728698730469],
#   ['embedding_034626', 'profile_012453', 46.81032943725586]]}

# %%
df[ df['has_detect_face'] == True ]
# Out:
#                                                              truth is_in_val  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000      True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001      True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001      True
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...  profile_000002      True
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...  profile_000002      True
# ...                                                            ...       ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...             NaN      True
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...             NaN      True
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...             NaN      True
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...             NaN      True
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...             NaN      True
#
#                                                    has_detect_face  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...            True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...            True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...            True
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...            True
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...            True
# ...                                                            ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...            True
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...            True
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...            True
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...            True
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...            True
#
#                                                         prediction
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...  profile_002298
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...  profile_011015
# ...                                                            ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...  profile_000618
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...  profile_011941
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...  profile_007683
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...  profile_011324
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...  profile_011470
#
# [13710 rows x 4 columns]

# %%
df.to_csv('./test_result.csv')

# %%
df[ df['truth'] == df['prediction'] ]
# Out:
#                                                              truth is_in_val  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000      True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001      True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001      True
# sowon_685583906b95f6b9aa555b96881aa2f80fea5692.jpg  profile_000015      True
# tobias_schramm_7b000a7857a56eb4fd29644ec12cd17e...  profile_000016      True
# ...                                                            ...       ...
# linh_trang_e50551b7916d3fae89eea8b88cad72564e53...  profile_012505      True
# ong_hoang_nam_952a11ca7273c499caad34283e6e99283...  profile_012508      True
# ong_hoang_nam_a8570425db9bb6928a402a8aaa2ae6972...  profile_012508      True
# le_phan_ngoc_lan_bc2d715c835d1dcf636e93d173aad2...  profile_012521      True
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...  profile_012524      True
#
#                                                    has_detect_face  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...            True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...            True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...            True
# sowon_685583906b95f6b9aa555b96881aa2f80fea5692.jpg            True
# tobias_schramm_7b000a7857a56eb4fd29644ec12cd17e...            True
# ...                                                            ...
# linh_trang_e50551b7916d3fae89eea8b88cad72564e53...            True
# ong_hoang_nam_952a11ca7273c499caad34283e6e99283...            True
# ong_hoang_nam_a8570425db9bb6928a402a8aaa2ae6972...            True
# le_phan_ngoc_lan_bc2d715c835d1dcf636e93d173aad2...            True
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...            True
#
#                                                         prediction
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001
# sowon_685583906b95f6b9aa555b96881aa2f80fea5692.jpg  profile_000015
# tobias_schramm_7b000a7857a56eb4fd29644ec12cd17e...  profile_000016
# ...                                                            ...
# linh_trang_e50551b7916d3fae89eea8b88cad72564e53...  profile_012505
# ong_hoang_nam_952a11ca7273c499caad34283e6e99283...  profile_012508
# ong_hoang_nam_a8570425db9bb6928a402a8aaa2ae6972...  profile_012508
# le_phan_ngoc_lan_bc2d715c835d1dcf636e93d173aad2...  profile_012521
# nguyen_thi_mai_ka_d2ca55075502fcfd2c61f2bd99cd0...  profile_012524
#
# [7467 rows x 4 columns]

# %%
df[ df['is_in_val'] == True ]
# Out:
#                                                              truth is_in_val  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000      True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001      True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001      True
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...  profile_000002      True
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...  profile_000002      True
# ...                                                            ...       ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...             NaN      True
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...             NaN      True
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...             NaN      True
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...             NaN      True
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...             NaN      True
#
#                                                    has_detect_face  \
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...            True
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...            True
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...            True
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...            True
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...            True
# ...                                                            ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...            True
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...            True
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...            True
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...            True
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...            True
#
#                                                         prediction
# son_tung_ba35896e20d1430ca11bd05b4a52c073ae18a1...  profile_000000
# hari_won_81c3b0a93343051452695d92dc9ad658f1bf60...  profile_000001
# hari_won_a84c21610bdec19752b0bf95da9bc7b5e5d3ea...  profile_000001
# ho_quang_hieu_e01ffcb608bcd21746da62c9a2543bd3b...  profile_002298
# ho_quang_hieu_dcc5e659b6bc7738ddf226f54bdbf1e4c...  profile_011015
# ...                                                            ...
# ha_kim_tuyen_9a2abb7626ff23d2a578f5170de17feeb0...  profile_000618
# thu_ha_40215bc9ed6f5789dc628457f2ec5d03e6ee0424...  profile_011941
# beth_jordan_f81bbc4faf84fb1c10d9a47dab6cc9fe270...  profile_007683
# tina_turner_91ff2bcf8d137031497ac18bd3b55e19292...  profile_011324
# dixon_guido_ea45ceb8405b8450a4e2692a9f46d36ca65...  profile_011470
#
# [13866 rows x 4 columns]
